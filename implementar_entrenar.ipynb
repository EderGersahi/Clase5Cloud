# %% [markdown]
# ## Implementar/entrenar modelo

# %%
from sklearn.metrics import classification_report
from TheModel import build

import matplotlib.pyplot as plt
import numpy as np

# %%
local_model = build.build_it()
# Out:
# c:\Users\gersa\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
data = np.load('mnist_eder.npz') #variar el archivo, dependiendo al nombre del integrante
x_train_local = data['x_train_local']
y_train_local = data['y_train_local']
x_test = data['x_test']
y_test = data['y_test']

# %%
print(x_train_local.shape)
print(x_test.shape)
print(y_train_local.shape)
print(y_test.shape)
# Out:
# (12000, 28, 28, 1)
# (10000, 28, 28, 1)
# (12000,)
# (10000,)

# %%
history = local_model.fit(x_train_local , y_train_local, epochs=10, validation_data=(x_test,y_test))
y_pred = local_model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_classes))

plt.plot(history.history['accuracy'], label='Training accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
local_model.save("model_eder.keras")#Guardar el modelo, dependiendo al nombre del integrante
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7206 - loss: 0.8760 - val_accuracy: 0.9611 - val_loss: 0.1353
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9594 - loss: 0.1320 - val_accuracy: 0.9705 - val_loss: 0.0966
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9754 - loss: 0.0853 - val_accuracy: 0.9753 - val_loss: 0.0767
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9787 - loss: 0.0657 - val_accuracy: 0.9806 - val_loss: 0.0589
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9864 - loss: 0.0451 - val_accuracy: 0.9769 - val_loss: 0.0678
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9869 - loss: 0.0422 - val_accuracy: 0.9812 - val_loss: 0.0544
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9910 - loss: 0.0296 - val_accuracy: 0.9822 - val_loss: 0.0554
# Epoch 8/10
# ...
